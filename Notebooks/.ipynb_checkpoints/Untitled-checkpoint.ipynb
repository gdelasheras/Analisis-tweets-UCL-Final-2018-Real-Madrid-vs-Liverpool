# %% [markdown]
# # Proyecto final. Datamining.
# ### Análisis tweets UEFA Champions League Final 2018
#
# ### Participantes:
#
# Gonzalo de las Heras de Matías - Jorge de la Fuente Tagarro - Alejandro Amarillas Cámara - Sergio Sampio Balmaseda.
#
# ### Notebook (1/4). Preprocesamiento y transformación del dataset.
#
# ### Objetivo del notebook:
#
# Este notebook se centra en preprocesar el dataset, limpiando las columnas existentes y generando aquellas nuevas que sean necesarias.<br><br>
#
# ![title](Images/background.jpg)

# %% [markdown]
# #### Librerias

# %%
import pandas as pd
import numpy as np
import string
import math
import re
import nltk
import sys
import goslate
from matplotlib import *
from pylab import *
from datetime import datetime, timedelta
from wordcloud import WordCloud, STOPWORDS
from collections import Counter
from nltk.tokenize import TweetTokenizer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.corpus import wordnet as wn
from nltk.corpus import sentiwordnet as swn
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from google.oauth2 import service_account
from google.cloud import translate
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('sentiwordnet')
nltk.download('omw')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/gonzalo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/gonzalo/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package sentiwordnet to
# [nltk_data]     /Users/gonzalo/nltk_data...
# [nltk_data]   Package sentiwordnet is already up-to-date!
# [nltk_data] Downloading package omw to /Users/gonzalo/nltk_data...
# [nltk_data]   Package omw is already up-to-date!
# True

# %% [markdown]
# #### Funciones

# %%
# helper function to clean tweets
def ProcesarTweet(Tweet):
    # Remove HTML special entities (e.g. &amp;)
    Tweet = re.sub(r"\&\w*;", "", Tweet)
    #Convert @username to AT_USER
    Tweet = re.sub("@[^\s]+","",Tweet)
    Tweet = re.sub("\[[^\s]+\]","",Tweet)
    # Remove tickers
    Tweet = re.sub(r"\$\w*", "", Tweet)
    # To lowercase
    Tweet = Tweet.lower()
    # Remove hyperlinks
    Tweet = re.sub(r"https?:\/\/.*\/\w*", "", Tweet)
    Tweet = re.sub(r"https...", "", Tweet)
    
    Tweet = re.sub(r"á", "a", Tweet)
    Tweet = re.sub(r"é", "e", Tweet)
    Tweet = re.sub(r"í", "i", Tweet)
    Tweet = re.sub(r"ó", "o", Tweet)
    Tweet = re.sub(r"ú", "u", Tweet)
    # Remove hashtags
    Tweet = re.sub(r"#\w*", "", Tweet)
    # Remove Punctuation and split "s, "t, "ve with a space for filter
    Tweet = re.sub(r"[" + string.punctuation.replace("@", "") + "]+", " ", Tweet)
    # Remove words with 2 or fewer letters
    Tweet = re.sub(r"\b\w{1,2}\b", "", Tweet)
    # Remove whitespace (including new line characters)
    Tweet = re.sub(r"\s\s+", " ", Tweet)
    # Remove single space remaining at the front of the tweet.
    Tweet = Tweet.lstrip(" ") 
    # Remove characters beyond Basic Multilingual Plane (BMP) of Unicode:
    Tweet = "".join(c for c in Tweet if c <= "\uFFFF") 
    return Tweet

# %%
def text_process(raw_text):
    # Check characters to see if they are in punctuation
    nopunc = [char for char in list(raw_text) if char not in string.punctuation]
    # Join the characters again to form the string.
    nopunc = "".join(nopunc)
    
    # Now just remove any stopwords
    return [word for word in nopunc.lower().split() if word.lower() not in stopwords.words("english")]

# %%
def CodificarPalabra():
    return Palabra.encode("ascii", errors="ignore").decode()

# %% [markdown]
# ## 1. Carga de datos

# %%
DIR_DATASET_JSON = "/Users/gonzalo/Documents/Datasets/tweets-ucl-final-2018/data.json"

# %%
if "json" not in globals():
    json = pd.read_json(DIR_DATASET_JSON, lines=True)

# %% [markdown]
# #### 1.3 Construcción dataset final

# %%
data = json.copy()
Dataset_Final = pd.DataFrame()

# %% [markdown]
# ## 2. Limpieza de datos

# %% [markdown]
# Primera fase del proceso de KDD en el que limpiamos los datos

# %% [markdown]
# ### 2.1 Eliminación de columnas

# %% [markdown]
# #### 2.1.1 Coordinates

# %%
if len(data[data['coordinates'] == None].index) == 0:
    print("La columna 'coordinates' está toda a NaN, borrando columna.")
    del data['coordinates']
# Out:
# La columna 'coordinates' está toda a NaN, borrando columna.

# %% [markdown]
# #### 2.1.2 Contributors

# %%
if len(data[data['contributors'] == data['contributors']].index) == 0:
    print("La columna 'contributors' está toda a NaN, borrando columna.")

del data['contributors']
# Out:
# La columna 'contributors' está toda a NaN, borrando columna.

# %% [markdown]
# #### 2.1.3 Withheld_in_countries

# %%
withheld_in_countries = len(data[data['withheld_in_countries'] == data['withheld_in_countries']].index)
if  withheld_in_countries== 0:
    print("La columna 'withheld_in_countries' está toda a NaN, borrando columna.")
    del data['withheld_in_countries']
else:
     print('Hay ', withheld_in_countries, "ocurrencias")
# Out:
# Hay  153 ocurrencias

# %% [markdown]
# Hay muy pocas ocurrencias que no sean nulas, eliminamos la columna entera al no ser de utilidad.

# %%
del data['withheld_in_countries']

# %% [markdown]
# #### 2.1.4 favorite_count

# %%
favorite_count = len(data[data['favorite_count'] != 0.0].index)
if  favorite_count == 0:
    print("La columna 'favorite_count' está toda a 0.0")
    del data['favorite_count']
else:
    print('Hay ', favorite_count, "ocurrencias")
# Out:
# Hay  24202 ocurrencias

# %% [markdown]
# #### 2.1.5 geo

# %%
geo_count = len(data[data['geo'] == None].index)
if geo_count == 0:
    print("La columna 'geo' está toda a NaN, borrando columna.")
    del data['geo']
else:
    print('Hay ', geo_count, "ocurrencias")
# Out:
# La columna 'geo' está toda a NaN, borrando columna.

# %% [markdown]
# #### 2.1.6 filter_level

# %%
filter_level_count = len(data['filter_level'].unique().tolist())
if filter_level_count == 1:
    print("La columna 'filter_level' es siempre igual.")
    del data['filter_level']
else:
    print('Hay ', filter_level_count, "valores distintos")
# Out:
# Hay  2 valores distintos

# %% [markdown]
# #### 2.1.6 place (se recogerá la información en la parte de usuarios)

# %% [markdown]
# Después de haber probado unos cuentos, nos quedamos con la localizacion de los usurios, casi siempre es la misma.

# %%
del data['place']

# %% [markdown]
# #### 2.1.8 Campos que no aportan información

# %%
del data['display_text_range']
del data['truncated']

# %% [markdown]
# ### 2.2 Eliminación filas

# %% [markdown]
# #### 2.2.1 Eliminación filas nulas

# %%
data = data.drop(data[data['id'] != data['id']].id.index)
data = data.reset_index(drop=True)

Dataset_Final['id'] = data['id'].astype('int64')
del data['id']
del data['id_str']

# %% [markdown]
# ### 2.3 Volcado al dataset final

# %% [markdown]
# #### 2.2.2 Conversión de fecha completa a solo tiempo (todos los tweets son del mismo día)

# %%
data['created_at'] += pd.DateOffset(hours=2) 
Dataset_Final['hora'] = data['created_at'].dt.time
Dataset_Final['hora'] = Dataset_Final['hora'] 
del data['created_at']
del data['timestamp_ms']

# %% [markdown]
# #### 2.2.3 Formateo de fuente (plataforma desde el que se lanza el tweet)

# %%
Dataset_Final['fuente'] = data['source'].replace('<a[^>]*>([^<]+)<\/a>', r'\1', regex=True)

Dataset_Final.loc[Dataset_Final['fuente'] == 'Twitter for Android', 'fuente'] = 'Android'
Dataset_Final.loc[Dataset_Final['fuente'] == 'Twitter for iPhone', 'fuente']  = 'iPhone'
Dataset_Final.loc[Dataset_Final['fuente'] == 'Twitter for iPad', 'fuente']  = 'iPad'
Dataset_Final.loc[Dataset_Final['fuente'] == 'Twitter Web Client', 'fuente']  = 'Twitter Web'
del data['source']

# %% [markdown]
# #### 2.2.4 Idioma

# %%
Dataset_Final['idioma'] = data['lang']
del data['lang']

# %% [markdown]
# #### 2.2.5 Id tweet respuesta

# %%
data['in_reply_to_status_id'].fillna(-1)
Dataset_Final['tweet_respuesta_id'] = data['in_reply_to_status_id']
del data['in_reply_to_status_id']
del data['in_reply_to_status_id_str']

# %% [markdown]
# #### 2.2.6 Id usuario tweet respuesta

# %%
data['in_reply_to_user_id'].fillna(-1)
Dataset_Final['tweet_respuesta_usuario_id'] = data['in_reply_to_user_id']
del data['in_reply_to_user_id']
del data['in_reply_to_user_id_str']

# %% [markdown]
# #### 2.2.7 Nombre usuario tweet respuesta

# %%
data['in_reply_to_screen_name'].fillna(-1)
Dataset_Final['tweet_respuesta_nombre_twitter'] = data['in_reply_to_screen_name']
del data['in_reply_to_screen_name']

# %% [markdown]
# #### 2.2.8 Información anidada

# %%
id_usuarios = []
name = [] 
screen_name = []
description = []
verified = []
location = []
followers_count = []
listed_count = []
favourites_count = []
created_at = []
usuario_lang = []
statuses_count = []
text = []
hashtag = []

user_mentions_screen_name = []
user_mentions_id = []
user_mentions_name = []

for index, row in data.iterrows():
    datos_usuario = row["user"]
    extended_tweet = row["extended_tweet"]
    entities = row["entities"] 
    
    statuses_count.append(datos_usuario["statuses_count"])
    location.append(datos_usuario["location"])
    id_usuarios.append(datos_usuario["id"])
    name.append(datos_usuario["name"])
    screen_name.append(datos_usuario["screen_name"])
    description.append(datos_usuario["description"])
    verified.append(datos_usuario["verified"])
    followers_count.append(datos_usuario["followers_count"])
    favourites_count.append(datos_usuario["favourites_count"])
    created_at.append(datos_usuario["created_at"])
    usuario_lang.append(datos_usuario["lang"])
    
    # Menciones en un tweet.
    user_mentions_screen_name_temp = []
    user_mentions_id_temp = []
    user_mentions_name_temp = []
    
    for user in entities["user_mentions"]:
        user_mentions_screen_name_temp.append(user["screen_name"])
        user_mentions_id_temp.append(user["id"])
        user_mentions_name_temp.append(user["name"])
        
    if len(user_mentions_screen_name_temp) > 0:
        user_mentions_screen_name.append(user_mentions_screen_name_temp)
    else:
        user_mentions_screen_name.append(-1)
        
    if len(user_mentions_id_temp) > 0:
        user_mentions_id.append(user_mentions_id_temp)
    else:
        user_mentions_id.append(-1)
        
    if len(user_mentions_name_temp) > 0:
        user_mentions_name.append(user_mentions_name_temp)
    else:
        user_mentions_name.append(-1)
    
    if extended_tweet is not "nan":
        text.append(row["text"])
        hashtags_temp = []
        for i in range(0, len(entities["hashtags"])):
            hashtags_temp.append(entities["hashtags"][i]["text"].lower())
        if len(hashtags_temp) > 0:
            hashtag.append(hashtags_temp)
        else:
            hashtag.append(-1)
    else:
        text.append(extended_tweet["full_text"])
        hashtags_temp = []
        for i in range(0, len(extended_tweet["entities"]["hashtags"])):
               hashtags_temp.append(extended_tweet["entities"]["hashtags"][i]["text"].lower())
        if len(hashtags_temp) > 0:
            hashtag.append(hashtags_temp)
        else:
            hashtag.append(-1)

# %%
Dataset_Final['usuario_id'] = id_usuarios
Dataset_Final['usuario_nombre'] = name
Dataset_Final['usuario_nombre_twitter'] = screen_name
Dataset_Final['usuario_localizacion'] = location
Dataset_Final['usuario_idioma'] = usuario_lang
Dataset_Final['usuario_verificado'] = verified
Dataset_Final['usuario_numero_seguidores'] = followers_count
Dataset_Final['usuario_numero_favoritos_hechos'] = favourites_count
Dataset_Final['usuario_numero_tweets'] = statuses_count
Dataset_Final['usuario_numero_creacion'] = created_at
Dataset_Final['hashtag'] = hashtag
Dataset_Final['texto_original'] = text
Dataset_Final['mencion_usuario_id'] = user_mentions_id
Dataset_Final['mencion_usuario_nombre'] = user_mentions_name
Dataset_Final['mencion_usuario_nombre_twitter'] = user_mentions_screen_name

del data['user']
del data['entities']

# %%
#Dataset_Final = Dataset_Final[:50]
#Dataset_Final
# Out:
#                      id      hora        fuente idioma  tweet_respuesta_id  \
# 0   1000365563376488448  15:18:30     Hootsuite     en                 NaN
# 1   1000365564190048256  15:18:31       Android     in                 NaN
# 2   1000365564320247808  15:18:31       Android     es                 NaN
# 3   1000365564357832704  15:18:31   Madridista2     es                 NaN
# 4   1000365564517388288  15:18:31       Android     en                 NaN
# 5   1000365564781580288  15:18:31   Twitter Web     en                 NaN
# 6   1000365565125513216  15:18:31       Android     sv                 NaN
# 7   1000365565154742272  15:18:31       Android     en                 NaN
# 8   1000365565314322432  15:18:31       Android     en                 NaN
# 9   1000365565708513280  15:18:31        iPhone     ar                 NaN
# 10  1000365566320881664  15:18:31       Android     en                 NaN
# 11  1000365566224486400  15:18:31       Android    und                 NaN
# 12  1000365567000350720  15:18:31       Android     fr                 NaN
# 13  1000365567402958848  15:18:31        iPhone     en                 NaN
# 14  1000365567856009216  15:18:31       Android     pt                 NaN
# 15  1000365568250146816  15:18:32        iPhone     en                 NaN
# 16  1000365568506171392  15:18:32   Twitter Web     fr                 NaN
# 17  1000365568648593408  15:18:32       Android     en                 NaN
# 18  1000365569311375360  15:18:32       Android     en                 NaN
# 19  1000365568875290624  15:18:32       Android     en        1.000364e+18
# 20  1000365569940574208  15:18:32       Android     es                 NaN
# 21  1000365570297073664  15:18:32        iPhone     fr                 NaN
# 22  1000365570456465408  15:18:32       Android     en                 NaN
# 23  1000365571458961408  15:18:32   Twitter Web     ar                 NaN
# 24  1000365572658515968  15:18:33       Android     fr                 NaN
# 25  1000365572545101824  15:18:33        iPhone     en                 NaN
# 26  1000365572729835520  15:18:33       Android     fr                 NaN
# 27  1000365573828562944  15:18:33       Android     en                 NaN
# 28  1000365574474686464  15:18:33       Android     en                 NaN
# 29  1000365574713638912  15:18:33     Instagram     en                 NaN
# 30  1000365574332051456  15:18:33        iPhone     en                 NaN
# 31  1000365574986203136  15:18:33  Twitter Lite     en                 NaN
# 32  1000365575141494784  15:18:33       Android     en                 NaN
# 33  1000365575468658688  15:18:33   Twitter Web     en                 NaN
# 34  1000365575816794112  15:18:33       Android    und                 NaN
# 35  1000365575892283392  15:18:33   Twitter Web     ar                 NaN
# 36  1000365576311726080  15:18:33        iPhone     fr                 NaN
# 37  1000365577200914432  15:18:34        iPhone     en                 NaN
# 38  1000371333501505536  15:41:26       Android     fr                 NaN
# 39  1000371333807656960  15:41:26        iPhone     en                 NaN
# 40  1000371333992071168  15:41:26       Android     in                 NaN
# 41  1000371334675918848  15:41:26       Android     fr                 NaN
# 42  1000371334386462720  15:41:26   Twitter Web    und                 NaN
# 43  1000371335372013568  15:41:27        iPhone     en                 NaN
# 44  1000371336550735872  15:41:27       Android     en                 NaN
# 45  1000371336634687488  15:41:27        iPhone     en                 NaN
# 46  1000371337049735168  15:41:27       Android     en                 NaN
# 47  1000371338643582976  15:41:27       Android     en                 NaN
# 48  1000371340845768704  15:41:28          iPad     en                 NaN
# 49  1000371341055397888  15:41:28        iPhone     ar                 NaN
#
#     tweet_respuesta_usuario_id tweet_respuesta_nombre_twitter  \
# 0                          NaN                           None
# 1                          NaN                           None
# 2                          NaN                           None
# 3                          NaN                           None
# 4                          NaN                           None
# 5                          NaN                           None
# 6                          NaN                           None
# 7                          NaN                           None
# 8                          NaN                           None
# 9                          NaN                           None
# 10                         NaN                           None
# 11                         NaN                           None
# 12                         NaN                           None
# 13                         NaN                           None
# 14                         NaN                           None
# 15                         NaN                           None
# 16                         NaN                           None
# 17                         NaN                           None
# 18                         NaN                           None
# 19                2.175401e+09                      drremish_
# 20                         NaN                           None
# 21                         NaN                           None
# 22                         NaN                           None
# 23                         NaN                           None
# 24                         NaN                           None
# 25                         NaN                           None
# 26                         NaN                           None
# 27                         NaN                           None
# 28                         NaN                           None
# 29                         NaN                           None
# 30                         NaN                           None
# 31                         NaN                           None
# 32                         NaN                           None
# 33                         NaN                           None
# 34                         NaN                           None
# 35                         NaN                           None
# 36                         NaN                           None
# 37                         NaN                           None
# 38                         NaN                           None
# 39                         NaN                           None
# 40                         NaN                           None
# 41                         NaN                           None
# 42                         NaN                           None
# 43                         NaN                           None
# 44                         NaN                           None
# 45                         NaN                           None
# 46                         NaN                           None
# 47                         NaN                           None
# 48                         NaN                           None
# 49                         NaN                           None
#
#              usuario_id                        usuario_nombre  \
# 0            2846595478  Real Madrid vs Liverpool Live stream
# 1            2917613580                    Individu Merdeka ☮
# 2    946054253461852160                Roberto Esperón alonso
# 3             962840767                             R.Madrid™
# 4    902735000445095938                             Kwame-Nat
# 5             240672622                         NOSA TOPNOTCH
# 6             311037764                                Sredny
# 7             277019564                            kenyan kop
# 8    957644286350315521                        Abdulai Suburu
# 9            1672941752                     medo_hazazi9 N18💛
# 10           4057128733                                     c
# 11           2485857084                        Santiago Ortiz
# 12   751548692310745093                            Arif Ahmed
# 13            310129970                              Shairuz©
# 14           3662137997                          Sandro Ramos
# 15           2181170941          ЭМЧ СУВИЛАГЧИЙН ЦАЛИН НЭМ!!!
# 16           2179927857                                  neki
# 17            368684229                      Syahir Saifuddin
# 18            468156334                   Omoruyi Efe (Eddie)
# 19            156953469                          Aissa ® Culé
# 20   731541114449235969                         Daniel Rivero
# 21           3021031221                           tortue gégé
# 22            117007547                    michael munyanyiwa
# 23           2465062267                                   ليث
# 24           2423051170                          Rosero Mario
# 25             15081867                     مرتضى عيسى #سيهات
# 26            173510700                        Lucão da Massa
# 27   914789110274973697                              Mustapha
# 28            448214562                          Nurein I Ncd
# 29             27414664                         Andy Senyszyn
# 30             60882787                              Nyame Ye
# 31            440610547                                     💖
# 32   829715415513366528                           Hedwig⁦ 🦉🙏🏻
# 33   707300223111065600                         joshuamuriuki
# 34   947417511443738624                            #AporLa13🏆
# 35           2465097264                                 شيماء
# 36           2269512156                                tirado
# 37            706392896                     Phillip Barringer
# 38             80941489                          Nick Ledgers
# 39  1000055636535730177                          Alan Johnson
# 40   722846492952633344                Jampang VS gabener VOC
# 41   707778529518178304                         Vishal Telang
# 42   940491053924343808                                   FFF
# 43   889807304341700608                                   みきと
# 44   783931151798964225                               BRANDON
# 45            163496759                        Ollie Kendrick
# 46            308918274                     Muhammad Zulhelmi
# 47   944438800322670592            หมวย🤗🤗🤗🤗ฉันจะยังเหมือนเดิม
# 48            311475717                         Brylcreem Boy
# 49           2415642071                         محمد الدعجاني
#
#    usuario_nombre_twitter                        ...                          \
# 0                  UCL_TV                        ...
# 1               Raditakia                        ...
# 2          esperon_alonso                        ...
# 3             RMadridIsco                        ...
# 4              Kwame_Nat1                        ...
# 5            nosatopnotch                        ...
# 6                 SredXNY                        ...
# 7               Kenyankop                        ...
# 8           SuburuAbdulai                        ...
# 9                rory4000                        ...
# 10                EchosOG                        ...
# 11         SANTIAGOORTIZE                        ...
# 12          floatingpast0                        ...
# 13               Tayruzzz                        ...
# 14              linesanrj                        ...
# 15               BtUyanga                        ...
# 16         fatlum_qerkini                        ...
# 17        SyahirSaifuddin                        ...
# 18           Eddie11stats                        ...
# 19           IsaOfficial7                        ...
# 20         danifaneguitas                        ...
# 21                turin39                        ...
# 22             jackbond07                        ...
# 23             MihalQiana                        ...
# 24          mariorosero49                        ...
# 25                saihati                        ...
# 26              Lucas_998                        ...
# 27           Mustapha1759                        ...
# 28              nurein4me                        ...
# 29              zhgingaah                        ...
# 30             KwameAddai                        ...
# 31            fetchingoth                        ...
# 32           HadeelMelhem                        ...
# 33              mukiijosh                        ...
# 34         Silvafilipe155                        ...
# 35                 MDlhia                        ...
# 36                Azuruoo                        ...
# 37          barringerphil                        ...
# 38            nickledgers                        ...
# 39         AlanJohnLondon                        ...
# 40          putra_bisma12                        ...
# 41             vishaliimb                        ...
# 42         France_de_Foot                        ...
# 43         mikito69reysol                        ...
# 44        GrinningBrandon                        ...
# 45          OllieKendrick                        ...
# 46        muhd_zulhelmi93                        ...
# 47        LNi92vlkxd053gh                        ...
# 48          Brylcream_Boy                        ...
# 49                  6Wa7d                        ...
#
#    usuario_verificado usuario_numero_seguidores  \
# 0               False                     15294
# 1               False                       530
# 2               False                       234
# 3               False                     90905
# 4               False                       364
# 5               False                      1322
# 6               False                       238
# 7               False                      1423
# 8               False                       427
# 9               False                       812
# 10              False                       634
# 11              False                      1420
# 12              False                       151
# 13              False                       687
# 14              False                       104
# 15              False                      3897
# 16              False                      2219
# 17              False                       505
# 18              False                       669
# 19              False                       372
# 20              False                        56
# 21              False                        89
# 22              False                        52
# 23              False                     10141
# 24              False                        23
# 25              False                       866
# 26              False                       158
# 27              False                         0
# 28              False                       508
# 29              False                       500
# 30              False                      1028
# 31              False                     10779
# 32              False                        16
# 33              False                        69
# 34              False                       391
# 35              False                     13189
# 36              False                        94
# 37              False                       196
# 38              False                       277
# 39              False                        18
# 40              False                      1223
# 41              False                       121
# 42              False                       549
# 43              False                       260
# 44              False                      5080
# 45              False                       351
# 46              False                       351
# 47              False                        38
# 48              False                       895
# 49              False                       294
#
#     usuario_numero_favoritos_hechos  usuario_numero_tweets  \
# 0                              3281                  24148
# 1                              5608                  41354
# 2                             26179                  18715
# 3                              1192                   2619
# 4                              5274                   2817
# 5                                 6                   5984
# 6                                44                  23289
# 7                             21417                  17163
# 8                             31400                  33042
# 9                               492                  10528
# 10                             6998                   9217
# 11                           387943                 396292
# 12                            51608                  18499
# 13                            10734                  38938
# 14                            17515                   7034
# 15                            10204                   5202
# 16                            17958                 131010
# 17                            22866                  72145
# 18                               32                  39033
# 19                             2548                  16779
# 20                             4465                    795
# 21                              936                    883
# 22                              234                     74
# 23                              683                  74850
# 24                               19                    144
# 25                             7043                  30189
# 26                             8463                   6642
# 27                               10                      8
# 28                             3804                  43430
# 29                            36325                   9901
# 30                              706                  13760
# 31                              618                  15594
# 32                              480                    252
# 33                              506                    166
# 34                            14049                   6408
# 35                              671                  75053
# 36                             6532                   5252
# 37                             1083                   2113
# 38                            65407                  75717
# 39                              522                    521
# 40                            76410                 105524
# 41                              929                   2651
# 42                               94                    518
# 43                             3301                   1203
# 44                            11549                   5892
# 45                            13268                   6765
# 46                             2480                  19640
# 47                            34550                 124896
# 48                              934                  21632
# 49                            13325                  13308
#
#            usuario_numero_creacion  \
# 0   Mon Oct 27 11:38:12 +0000 2014
# 1   Wed Dec 03 13:58:11 +0000 2014
# 2   Wed Dec 27 16:24:45 +0000 2017
# 3   Wed Nov 21 18:09:54 +0000 2012
# 4   Wed Aug 30 03:29:30 +0000 2017
# 5   Thu Jan 20 13:32:14 +0000 2011
# 6   Sat Jun 04 19:53:17 +0000 2011
# 7   Mon Apr 04 14:55:41 +0000 2011
# 8   Sun Jan 28 15:59:24 +0000 2018
# 9   Thu Aug 15 11:18:14 +0000 2013
# 10  Thu Oct 29 11:32:55 +0000 2015
# 11  Fri May 09 20:55:29 +0000 2014
# 12  Fri Jul 08 22:49:06 +0000 2016
# 13  Fri Jun 03 07:25:17 +0000 2011
# 14  Tue Sep 15 08:44:30 +0000 2015
# 15  Fri Nov 08 00:51:32 +0000 2013
# 16  Wed Nov 13 18:46:23 +0000 2013
# 17  Tue Sep 06 01:54:40 +0000 2011
# 18  Thu Jan 19 07:11:46 +0000 2012
# 19  Fri Jun 18 11:55:01 +0000 2010
# 20  Sat May 14 17:46:07 +0000 2016
# 21  Fri Feb 06 05:38:15 +0000 2015
# 22  Wed Feb 24 07:19:38 +0000 2010
# 23  Sat Apr 26 19:46:22 +0000 2014
# 24  Wed Mar 19 17:45:53 +0000 2014
# 25  Wed Jun 11 05:30:41 +0000 2008
# 26  Sun Aug 01 17:32:25 +0000 2010
# 27  Mon Oct 02 09:48:14 +0000 2017
# 28  Tue Dec 27 19:05:55 +0000 2011
# 29  Sun Mar 29 12:01:27 +0000 2009
# 30  Tue Jul 28 11:50:37 +0000 2009
# 31  Mon Dec 19 06:19:45 +0000 2011
# 32  Thu Feb 09 15:35:45 +0000 2017
# 33  Tue Mar 08 20:21:29 +0000 2016
# 34  Sun Dec 31 10:41:51 +0000 2017
# 35  Sat Apr 26 20:43:56 +0000 2014
# 36  Mon Dec 30 22:36:38 +0000 2013
# 37  Fri Jul 20 04:04:55 +0000 2012
# 38  Thu Oct 08 20:56:27 +0000 2009
# 39  Fri May 25 16:46:58 +0000 2018
# 40  Wed Apr 20 17:56:48 +0000 2016
# 41  Thu Mar 10 04:02:06 +0000 2016
# 42  Tue Dec 12 07:58:35 +0000 2017
# 43  Tue Jul 25 11:19:27 +0000 2017
# 44  Thu Oct 06 07:25:26 +0000 2016
# 45  Tue Jul 06 15:29:53 +0000 2010
# 46  Wed Jun 01 06:41:19 +0000 2011
# 47  Sat Dec 23 05:25:31 +0000 2017
# 48  Sun Jun 05 14:31:33 +0000 2011
# 49  Sun Mar 16 17:08:53 +0000 2014
#
#                                               hashtag  \
# 0                                     [uclfinal, lfc]
# 1                                [uclfinal, sportone]
# 2                        [innovateyourgame, uclfinal]
# 3                                                  -1
# 4                                          [uclfinal]
# 5                                                  -1
# 6                                          [uclfinal]
# 7                                          [uclfinal]
# 8                              [uclfinal, laysunited]
# 9                                          [uclfinal]
# 10                                         [uclfinal]
# 11                         [uclfinal, weareliverpool]
# 12                                         [uclfinal]
# 13                                         [uclfinal]
# 14                   [uclfinal, aporla13, halamadrid]
# 15                                         [uclfinal]
# 16                              [believers, uclfinal]
# 17                                         [uclfinal]
# 18                                         [uclfinal]
# 19                                                 -1
# 20                                              [ucl]
# 21                              [believers, uclfinal]
# 22                          [uclfinal, realliverpool]
# 23       [رحلات_سياحيه_في_ماليزيا_2018رحلا, uclfinal]
# 24                              [believers, uclfinal]
# 25                                         [uclfinal]
# 26                              [believers, uclfinal]
# 27                                                 -1
# 28                               [sharethedrama, ucl]
# 29                                         [uclfinal]
# 30                                                 -1
# 31                           [uclfinal, loveitliveit]
# 32                   [aporla13, uclfinal, halamadrid]
# 33                  [uclfinal, nairobian, nysscandal]
# 34                   [uclfinal, aporla13, halamadrid]
# 35       [رحلات_سياحيه_في_ماليزيا_2018رحلا, uclfinal]
# 36                              [believers, uclfinal]
# 37                              [ynwa, uclfinal, lfc]
# 38                              [believers, uclfinal]
# 39                                         [uclfinal]
# 40                                         [uclfinal]
# 41                              [believers, uclfinal]
# 42  [uefa, europe, liguedeschampions, championslea...
# 43                                         [uclfinal]
# 44                                         [uclfinal]
# 45                                         [uclfinal]
# 46                                         [uclfinal]
# 47  [myheroวีรบุรุษสุดที่รัก, toyotathaileague, แช...
# 48                                         [uclfinal]
# 49                     [نهائي_دوري_الأبطال, uclfinal]
#
#                                        texto_original  \
# 0   MATCH-DAY\n\nReal Madrid vs Liverpool\n\n#UCLF...
# 1   RT @panditfootball: [VIDEO] Siapa yang punya p...
# 2   RT @madridismoreaI_: HA LLEGADO EL DÍA ⚽️\n\nH...
# 3   RT @madridismoreaI_: Mi XI  para mañana: Navas...
# 4   RT @ECG_Unofficial: We will like to categorica...
# 5   Real Madrid.... LETS GO!!!!!!!!!!!!!!!!!!!!!!!...
# 6   RT @ChampionsLeague: Klopp 🤣🤣🤣\n\n#UCLfinal ht...
# 7   RT @YNWA_Claire: Please? 🙏🏼\n\n#UCLFinal https...
# 8   RT @ChampionsLeague: Two European giants go he...
# 9   RT @LaLigaArab: سيد اللاعبين 🔝 @Cristiano 🔝\n\...
# 10  RT @ChampionsLeague: 🇪🇬 Mohamed Salah to becom...
# 11  RT @LFC: #UCLfinal day. 🔴\n\n#WeAreLiverpool h...
# 12  RT @LorisKarius: #UCLFINAL \nAllez Allez Allez...
# 13  RT @AyoDesigns: #UCLFinal.\nWho's winning it a...
# 14  RT @_Osblancos: Que chamada amigos ! Derrubamo...
# 15  RT @LFC: When you turn around and spot @Alex_O...
# 16  RT @LFC: 🎶 ALLEZ ALLEZ ALLEZ 🎶 \n\n#Believers ...
# 17  RT @ChampionsLeague: 🌎 Real Madrid v Liverpool...
# 18  RT @goal: Excitement level: 💯\n\nReal Madrid v...
# 19  @drremish_ @AaronStoneRocks @mantar1singh @Dyb...
# 20  RT @marca: Zidane avisa: "Estáis avisados" htt...
# 21  RT @LFCFrance: 🎶 ALLEZ ALLEZ ALLEZ 🎶 \n\n#Beli...
# 22             Real Murder!!!#UCLfinal #RealLiverpool
# 23  RT @malaysia_tours1: #رحلات_سياحيه_في_ماليزيا_...
# 24  RT @LFC: 🎶 ALLEZ ALLEZ ALLEZ 🎶 \n\n#Believers ...
# 25  RT @brfootball: Hyped. ⚪🔴\n\n#UCLfinal https:/...
# 26  RT @LFC: 🎶 ALLEZ ALLEZ ALLEZ 🎶 \n\n#Believers ...
# 27  RT @Sporf: 🎤 The world's biggest stars preview...
# 28  RT @Heineken_NG: The countdown to kickoff has ...
# 29  Gaff's ready, full kit w*nk*r style! #UCLFinal...
# 30  u think united n chelsea fans support liverpoo...
# 31  RT @DUALIPA: WHAT DAY IS IT?? SHOW DAY!!! Watc...
# 32  Let's get it again 😎😍😍\n#APorLa13  #UCLfinal #...
# 33  RT @digitolsol: Grab these products at a disco...
# 34  RT @_Osblancos: #UCLfinal #APorLa13 | #HalaMad...
# 35  RT @malaysia_tours1: #رحلات_سياحيه_في_ماليزيا_...
# 36  RT @LFC: 🎶 ALLEZ ALLEZ ALLEZ 🎶 \n\n#Believers ...
# 37  Walk on, walk on\nWith hope in your heart\nAnd...
# 38  RT @LFC: 🎶 ALLEZ ALLEZ ALLEZ 🎶 \n\n#Believers ...
# 39  RT @ChampionsLeague: The biggest game in Europ...
# 40  RT @SinarNKRI: Gibran, Kaesang dan Bobby Buka ...
# 41  RT @LFC: 🎶 ALLEZ ALLEZ ALLEZ 🎶 \n\n#Believers ...
# 42  #UEFA #Europe #LigueDesChampions #ChampionsLea...
# 43  RT @ChampionsLeague: The biggest game in Europ...
# 44  RT @LFC: We asked the players what will be goi...
# 45  RT @DavidBrentMovie: #UCLFinal day. I bloody l...
# 46  RT @ChampionsLeague: The biggest game in Europ...
# 47  RT @TopTrendThai: Twitter Trend\n2018-05-26 20...
# 48  RT @DavidBrentMovie: #UCLFinal day. I bloody l...
# 49  RT @Uefaworld1: 📸 تدريبات ليفربول @LFC_Arabic ...
#
#                                    mencion_usuario_id  \
# 0                                                  -1
# 1                                         [947281567]
# 2                    [188481426, 14872237, 291745825]
# 3                                         [188481426]
# 4                                        [2411233145]
# 5                                                  -1
# 6                                         [627673190]
# 7                                [932362455149408257]
# 8                                         [627673190]
# 9                     [827488482721402884, 155659213]
# 10                                        [627673190]
# 11                                         [19583545]
# 12                     [748881886248898561, 19583545]
# 13                                       [2632143718]
# 14                                       [4866003910]
# 15                              [19583545, 393028587]
# 16                                         [19583545]
# 17                                        [627673190]
# 18                                         [26809005]
# 19  [2175401051, 718346548, 853547509, 98635546140...
# 20                                         [15095537]
# 21                                        [988775689]
# 22                                                 -1
# 23                                       [2900115019]
# 24                                         [19583545]
# 25                                       [1561123663]
# 26                                         [19583545]
# 27                             [538031518, 627673190]
# 28                                        [368230671]
# 29                                                 -1
# 30                                                 -1
# 31                              [154101116, 18139619]
# 32                                                 -1
# 33                               [948834454755315712]
# 34                                       [4866003910]
# 35                                       [2900115019]
# 36                                         [19583545]
# 37                                                 -1
# 38                                         [19583545]
# 39                                        [627673190]
# 40                                       [3738356244]
# 41                                         [19583545]
# 42                                                 -1
# 43                                        [627673190]
# 44                                         [19583545]
# 45                                       [1270799208]
# 46                                        [627673190]
# 47                               [837126367779008512]
# 48                                       [1270799208]
# 49                           [1089626094, 1033035534]
#
#                                mencion_usuario_nombre  \
# 0                                                  -1
# 1                                [PanditFootball.com]
# 2   [Madridismo Real™, Real Madrid C.F. ⚽️, Nissan...
# 3                                  [Madridismo Real™]
# 4                                               [ECG]
# 5                                                  -1
# 6                                         [#UCLfinal]
# 7                                            [Claire]
# 8                                         [#UCLfinal]
# 9                         [LaLiga, Cristiano Ronaldo]
# 10                                        [#UCLfinal]
# 11                                     [Liverpool FC]
# 12                       [Loris Karius, Liverpool FC]
# 13                                              [Ayo]
# 14                                     [Os Galáticos]
# 15                [Liverpool FC, Alex Ox-Chamberlain]
# 16                                     [Liverpool FC]
# 17                                        [#UCLfinal]
# 18                                             [Goal]
# 19   [𝘳𝘦𝘮𝘪𝘴𝘩 𝘴𝘪𝘮𝘰𝘯, Amogh Sapre, Mantar Singh, Robin]
# 20                                            [MARCA]
# 21                                       [LFC France]
# 22                                                 -1
# 23                          [شركة مرشد الزائر العربي]
# 24                                     [Liverpool FC]
# 25                                     [B/R Football]
# 26                                     [Liverpool FC]
# 27                                 [SPORF, #UCLfinal]
# 28                                 [Heineken Nigeria]
# 29                                                 -1
# 30                                                 -1
# 31                                 [DUA LIPA, Pepsi™]
# 32                                                 -1
# 33                             [digital solutions 🇰🇪]
# 34                                     [Os Galáticos]
# 35                          [شركة مرشد الزائر العربي]
# 36                                     [Liverpool FC]
# 37                                                 -1
# 38                                     [Liverpool FC]
# 39                                        [#UCLfinal]
# 40                                       [Sinar NKRI]
# 41                                     [Liverpool FC]
# 42                                                 -1
# 43                                        [#UCLfinal]
# 44                                     [Liverpool FC]
# 45                                      [David Brent]
# 46                                        [#UCLfinal]
# 47                                     [TopTrendThai]
# 48                                      [David Brent]
# 49  [#نهائي_دوري_الأبطال | #UCLfinal 🏆, نادي ليفربول]
#
#                        mencion_usuario_nombre_twitter
# 0                                                  -1
# 1                                    [panditfootball]
# 2           [madridismoreaI_, realmadrid, Nissan_ESP]
# 3                                   [madridismoreaI_]
# 4                                    [ECG_Unofficial]
# 5                                                  -1
# 6                                   [ChampionsLeague]
# 7                                       [YNWA_Claire]
# 8                                   [ChampionsLeague]
# 9                             [LaLigaArab, Cristiano]
# 10                                  [ChampionsLeague]
# 11                                              [LFC]
# 12                                 [LorisKarius, LFC]
# 13                                       [AyoDesigns]
# 14                                       [_Osblancos]
# 15                               [LFC, Alex_OxChambo]
# 16                                              [LFC]
# 17                                  [ChampionsLeague]
# 18                                             [goal]
# 19  [drremish_, AaronStoneRocks, mantar1singh, Dyb...
# 20                                            [marca]
# 21                                        [LFCFrance]
# 22                                                 -1
# 23                                  [malaysia_tours1]
# 24                                              [LFC]
# 25                                       [brfootball]
# 26                                              [LFC]
# 27                           [Sporf, ChampionsLeague]
# 28                                      [Heineken_NG]
# 29                                                 -1
# 30                                                 -1
# 31                                   [DUALIPA, pepsi]
# 32                                                 -1
# 33                                       [digitolsol]
# 34                                       [_Osblancos]
# 35                                  [malaysia_tours1]
# 36                                              [LFC]
# 37                                                 -1
# 38                                              [LFC]
# 39                                  [ChampionsLeague]
# 40                                        [SinarNKRI]
# 41                                              [LFC]
# 42                                                 -1
# 43                                  [ChampionsLeague]
# 44                                              [LFC]
# 45                                  [DavidBrentMovie]
# 46                                  [ChampionsLeague]
# 47                                     [TopTrendThai]
# 48                                  [DavidBrentMovie]
# 49                           [Uefaworld1, LFC_Arabic]
#
# [50 rows x 22 columns]

# %%
Dataset_Final.fillna(-1, inplace=True)
Dataset_Final.tweet_respuesta_id = Dataset_Final.tweet_respuesta_id.astype(int)
Dataset_Final.tweet_respuesta_usuario_id = Dataset_Final.tweet_respuesta_usuario_id.astype(int)

# %% [markdown]
# ## Transformación y generación

# %%
Dataset_Final['texto_limpio'] = Dataset_Final['texto_original'].apply(ProcesarTweet)
Dataset_Final['texto_traducido'] = "-1"

# %%
credentials = service_account.Credentials.from_service_account_file("/Users/gonzalo/Documents/Keys/google.json")
translate_client = translate.Client(credentials=credentials)

terminado = False
    
print("Hay", len(Dataset_Final), "filas")

for index, row in Dataset_Final.iterrows():
    if index % 100 == 0:
        print(index, "filas traducidas.")
        
    if row["idioma"] != "en" and row["texto_traducido"] == "-1":
        
        # The target language
        target = 'en'

        # Translates some text into Russian
        translation = translate_client.translate(row["texto_limpio"], target_language=target)
        Dataset_Final.loc[index, 'texto_traducido'] = translation['translatedText']
        
    else:
        
        Dataset_Final.loc[index, 'texto_traducido'] = row['texto_limpio']
# Out:
# Hay 50 filas
# 0 filas traducidas.

# %%
vectorizer = TfidfVectorizer(max_df=0.5,max_features=10000,min_df=7,stop_words='english',use_idf=True)
X = vectorizer.fit_transform(Dataset_Final['texto_traducido'].str.upper())
sid = SentimentIntensityAnalyzer()
Dataset_Final['sentimiento_compound_polarity']=Dataset_Final["texto_traducido"].apply(lambda x:sid.polarity_scores(x)['compound'])
Dataset_Final['sentimiento_neutral']=Dataset_Final["texto_traducido"].apply(lambda x:sid.polarity_scores(x)['neu'])
Dataset_Final['sentimiento_negativo']=Dataset_Final["texto_traducido"].apply(lambda x:sid.polarity_scores(x)['neg'])
Dataset_Final['sentimiento_positivo']=Dataset_Final["texto_traducido"].apply(lambda x:sid.polarity_scores(x)['pos'])
Dataset_Final['sentimiento_tipo']= ""
Dataset_Final.loc[Dataset_Final['sentimiento_compound_polarity']>0,'sentimiento_tipo']='POSITIVE'
Dataset_Final.loc[Dataset_Final['sentimiento_compound_polarity']==0,'sentimiento_tipo']='NEUTRAL'
Dataset_Final.loc[Dataset_Final['sentimiento_compound_polarity']<0,'sentimiento_tipo']='NEGATIVE'

# %%
Dataset_Final['tokens'] = Dataset_Final['texto_traducido'].apply(text_process)

# %%
Dataset_Final.to_json("dataset_tweets.json")

# %%
Dataset_Final.head()
# Out:
#                     id      hora       fuente idioma  tweet_respuesta_id  \
# 0  1000365563376488448  15:18:30    Hootsuite     en                  -1
# 1  1000365564190048256  15:18:31      Android     in                  -1
# 2  1000365564320247808  15:18:31      Android     es                  -1
# 3  1000365564357832704  15:18:31  Madridista2     es                  -1
# 4  1000365564517388288  15:18:31      Android     en                  -1
#
#    tweet_respuesta_usuario_id tweet_respuesta_nombre_twitter  \
# 0                          -1                             -1
# 1                          -1                             -1
# 2                          -1                             -1
# 3                          -1                             -1
# 4                          -1                             -1
#
#            usuario_id                        usuario_nombre  \
# 0          2846595478  Real Madrid vs Liverpool Live stream
# 1          2917613580                    Individu Merdeka ☮
# 2  946054253461852160                Roberto Esperón alonso
# 3           962840767                             R.Madrid™
# 4  902735000445095938                             Kwame-Nat
#
#   usuario_nombre_twitter                        ...                          \
# 0                 UCL_TV                        ...
# 1              Raditakia                        ...
# 2         esperon_alonso                        ...
# 3            RMadridIsco                        ...
# 4             Kwame_Nat1                        ...
#
#   sentimiento_compound_polarity sentiment_neutral  sentiment_negativo  \
# 0                        0.5106             0.708                 0.0
# 1                        0.8316             0.476                 0.0
# 2                        0.0000             1.000                 0.0
# 3                        0.0000             1.000                 0.0
# 4                        0.8555             0.490                 0.0
#
#    sentiment_positivo  sentiment_tipo  sentimiento_neutral  \
# 0               0.292                                0.708
# 1               0.524                                0.476
# 2               0.000                                1.000
# 3               0.000                                1.000
# 4               0.510                                0.490
#
#   sentimiento_negativo sentimiento_positivo sentimiento_tipo  \
# 0                  0.0                0.292         POSITIVE
# 1                  0.0                0.524         POSITIVE
# 2                  0.0                0.000          NEUTRAL
# 3                  0.0                0.000          NEUTRAL
# 4                  0.0                0.510         POSITIVE
#
#                                               tokens
# 0  [match, day, real, madrid, liverpool, free, li...
# 1  [biggest, chance, becoming, 2018, champions, c...
# 2                        [come, day, ⚽️, make, real]
# 3  [tomorrow, navas, carvajal, nacho, ramos, marc...
# 4  [like, categorically, state, sincere, commitme...
#
# [5 rows x 34 columns]

# %%
fg

# %%
Dataset_Final

# %%
Dataset_Final.head()

# %%
# split sentences to get individual words
all_words = []
for line in Dataset_Final['tokens']: # try 'tokens'
    all_words.extend(line)
    
# create a word frequency dictionary
wordfreq = Counter(all_words)
# draw a Word Cloud with word frequencies
wordcloud = WordCloud(width=1600,
                      height=800,
                      max_words=200,
                      max_font_size=100,
                      relative_scaling=0.5,
                      colormap="ocean",
                      normalize_plurals=True).generate_from_frequencies(wordfreq)

plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
# split sentences to get individual words
all_words = []
for line in Dataset_Final[Dataset_Final['hashtag'] != -1]['hashtag']: # try 'tokens'
    all_words.extend(line)
    
# create a word frequency dictionary
wordfreq = Counter(all_words)

alice_mask = np.array(Image.open(path.join(d, "5.jpg")))

# draw a Word Cloud with word frequencies
wc = WordCloud(
                      max_words=50,
                      mask=alice_mask,
                      contour_color='steelblue').generate_from_frequencies(wordfreq)


# store to file
#wc.to_file(path.join(d, "alice.png"))
plt.figure(figsize=(17,14))
# show
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.figure()
plt.show()

# %%
Dataset_Final.loc[0].texto_limpio

# %%
translation

# %%
#!/usr/bin/env python
"""
Masked wordcloud
================

Using a mask you can generate wordclouds in arbitrary shapes.
"""

from os import path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

from wordcloud import WordCloud, STOPWORDS

# get data directory (using getcwd() is needed to support running example in generated IPython notebook)
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()

# Read the whole text.
text = open(path.join(d, '2.txt')).read()

# read the mask image
# taken from
# http://www.stencilry.org/stencils/movies/alice%20in%20wonderland/255fk.jpg
alice_mask = np.array(Image.open(path.join(d, "3.jpg")))

stopwords = set(STOPWORDS)
stopwords.add("said")

wc = WordCloud(background_color="white", max_words=2000, mask=alice_mask,
               stopwords=stopwords, contour_color='steelblue')

# generate word cloud
wc.generate(text)

# store to file
wc.to_file(path.join(d, "alice.png"))

# show
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.figure()
plt.imshow(alice_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis("off")
plt.show()
